# %%
#Ask for the Rating Algorithm
R = int(input('Enter 1 for Special Rating Algo and 2 for Standard Rating Algo. Your input = '))
M = int(input('Enter number of players(>10) = '))

#Pre-Tournament Ratings of Player
import random as random
B=[]
while len(B)< round(0.2*M):
    B.append(random.randrange(1500,1800))
while len(B)< round(0.9*M):
    B.append(random.randrange(1800,2150))
while len(B)<M:
     B.append(random.randrange(2150,2850))
#print B

#Tagging Players with Enrollment Numbers using dictionaries
A=[]
for i in range(1,len(B)+1):
    A.append('A'+str(i))
#print A
S=[]
for k in range(0,len(B)):
    S.append({'Name': A[k] , 'Rating':B[k] ,'PreSeasonRanking':1, 'pWe':0 , 'points':0  , 'RevRating':0 , 'FinalRating':0, 'PostSeasonRanking':1})
#print(1) # Replace by S to check 

#PreSeasonRanking
for y in range(0,len(S)):
    for z in range(0,len(S)):
        if (S[y])['Rating'] < (S[z])['Rating']:
            (S[y])['PreSeasonRanking'] =(S[y])['PreSeasonRanking'] +1

#Tournament Type: Single Round Robin
#provisional Winning expectancy
if R==1:
    for j in range(0,len(S)):
        for m in range(0,j):
            if (((S[j])['Rating'])-((S[m])['Rating']))>=400:
                (S[j])['pWe'] = (S[j])['pWe'] + 1
                (S[m])['pWe'] = (S[m])['pWe'] + 0
            elif (((S[j])['Rating'])-((S[m])['Rating']))<=-400:
                (S[j])['pWe'] = (S[j])['pWe'] + 0
                (S[m])['pWe'] = (S[m])['pWe'] + 1
            elif 0<(((S[j])['Rating'])-((S[m])['Rating']))<400:
                (S[j])['pWe'] = (S[j])['pWe'] + 0.5 + (((S[j])['Rating'])-((S[m])['Rating']))/800
                (S[m])['pWe'] = (S[m])['pWe'] + 0.5 - (((S[j])['Rating'])-((S[m])['Rating']))/800    
            elif -400<(((S[j])['Rating'])-((S[m])['Rating']))<0:
                (S[j])['pWe'] = (S[j])['pWe'] + 0.5 - (((S[j])['Rating'])-((S[m])['Rating']))/800
                (S[m])['pWe'] = (S[m])['pWe'] + 0.5 + (((S[j])['Rating'])-((S[m])['Rating']))/800     
elif R==2:
    for u in range(0,len(S)):
        for w in range(0,u):
            (S[u])['pWe'] = (S[u])['pWe'] + (1+10**(-(((S[u])['Rating'])-((S[w])['Rating']))/400))**(-1)
            (S[w])['pWe'] = (S[w])['pWe'] + (1+10**((((S[u])['Rating'])-((S[w])['Rating']))/400))**(-1)
                    
#print(2) #Replace by S to check


#Tournament starts
#Original Score
Q=[0,1,2,3,4,5]
for p in range(0,len(S)):
    for q in range(0,p):
        if (S[p])['Rating'] >2600 and (S[q])['Rating'] >2600:
            if Q[random.randrange(0,3,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,3,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,3,1)] == 2:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 2300 < (S[p])['Rating'] <= 2600 and (S[q])['Rating'] > 2600:
            if Q[random.randrange(0,4,1)] > 1 :
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,4,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif 1 < Q[random.randrange(0,4,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 1800 < (S[p])['Rating'] <= 2300 and (S[q])['Rating'] > 2600:
            if Q[random.randrange(0,5,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,5,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,5,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0  
        elif 1500 <= (S[p])['Rating'] <= 1800 and (S[q])['Rating'] > 2600:
            if Q[random.randrange(0,6,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,6,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,6,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0  
        elif (S[p])['Rating'] >2600 and 2300 < (S[q])['Rating'] <= 2600:
            if Q[random.randrange(0,4,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,4,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,4,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 2300 < (S[p])['Rating'] <= 2600 and 2300 < (S[q])['Rating'] <= 2600:
            if Q[random.randrange(0,3,1)] == 2 :
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,3,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif 1 < Q[random.randrange(0,3,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 1800 < (S[p])['Rating'] <= 2300 and 2300 < (S[q])['Rating'] <= 2600:
            if Q[random.randrange(0,4,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,4,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,4,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0  
        elif 1500 <= (S[p])['Rating'] <= 1800 and 2300 < (S[q])['Rating'] <= 2600:
            if Q[random.randrange(0,5,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,5,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,5,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0 
        elif (S[p])['Rating'] >2600 and 1800 < (S[q])['Rating'] <= 2300:
            if Q[random.randrange(0,5,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,5,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,5,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 2300 < (S[p])['Rating'] <= 2600 and 1800 < (S[q])['Rating'] <= 2300:
            if Q[random.randrange(0,4,1)] == 0 :
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,4,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif 1 < Q[random.randrange(0,4,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 1800 < (S[p])['Rating'] <= 2300 and 1800 < (S[q])['Rating'] <= 2300:
            if Q[random.randrange(0,3,1)] == 2:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,3,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,3,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0  
        elif 1500 <= (S[p])['Rating'] <= 1800 and 1800 < (S[q])['Rating'] <= 2300:
            if Q[random.randrange(0,4,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,4,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,4,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0         
        elif (S[p])['Rating'] >2600 and 1500 <= (S[q])['Rating'] <= 1800:
            if Q[random.randrange(0,6,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,6,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,6,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 2300 < (S[p])['Rating'] <= 2600 and 1500 <= (S[q])['Rating'] <= 1800:
            if Q[random.randrange(0,5,1)] == 0 :
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,5,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif 1 < Q[random.randrange(0,5,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0
        elif 1800 < (S[p])['Rating'] <= 2300 and 1500 <= (S[q])['Rating'] <= 1800:
            if Q[random.randrange(0,4,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,4,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,4,1)] > 1:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0  
        elif 1500 <= (S[p])['Rating'] <= 1800 and 1500 <= (S[q])['Rating'] <= 1800:
            if Q[random.randrange(0,3,1)] == 2:
                (S[p])['points'] = (S[p])['points'] + 0
                (S[q])['points'] = (S[q])['points'] + 1
            elif Q[random.randrange(0,3,1)] == 1:
                (S[p])['points'] = (S[p])['points'] + 0.5
                (S[q])['points'] = (S[q])['points'] + 0.5
            elif Q[random.randrange(0,3,1)] == 0:
                (S[p])['points'] = (S[p])['points'] + 1
                (S[q])['points'] = (S[q])['points'] + 0                         
#print(3) Replace by S to check 

#Rating after the tournament
for r in range(0,len(S)):
    (S[r])['RevRating'] = (S[r])['Rating'] + ((S[r])['points']-(S[r])['pWe'])
#print(4) #Replace by S to check

#Round off RevRating
for s in range(0,len(S)):
    (S[s])['FinalRating'] = (S[s])['FinalRating'] + round((S[s])['RevRating'])
#print(5)  #Replace by S to check

#PostSeasonRanking
for t in range(0,len(S)):
    for v in range(0,len(S)):
        if (S[t])['RevRating'] < (S[v])['RevRating']:
            (S[t])['PostSeasonRanking'] =(S[t])['PostSeasonRanking'] +1
#print(6) #Replace by S to check            

#rearranging the list
SortedS=[]
for d in range(0,len(S)+1):
    for f in range(0,len(S)):
        if (S[f])['PostSeasonRanking'] == d:
            SortedS.append(S[f])
#print(7) #Replace by SortedS to check            

#Get the csv file
import csv
with open('Scorecard.csv', 'w', newline='') as file:
    fieldnames = ['Name', 'Rating','PreSeasonRanking','pWe','points','RevRating','FinalRating','PostSeasonRanking']
    writer = csv.DictWriter(file, fieldnames=fieldnames, dialect='excel')
    writer.writeheader()
    writer.writerows(SortedS)
    
#writing with panda
import pandas
df = pandas.read_csv('Scorecard.csv')
df.to_csv('pandasplayers.csv')
writer = pandas.ExcelWriter('Scorecard.xlsx')
df.to_excel(writer, index = False)
writer.save()
# Out:
# Enter 1 for Special Rating Algo and 2 for Standard Rating Algo. Your input = 1
# Enter number of players(>10) = 25
